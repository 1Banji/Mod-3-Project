# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st

# %%
df = pd.read_csv('deathsdrug.csv')

# %%
df1 = pd.read_csv('total-gov-expenditure-percapita-OECD.csv')

# %%
df
# Out:
#            Entity Code  Year  70+ years (deaths)  50-69 years (deaths)  \
# 0     Afghanistan  AFG  1990           16.925449             58.650803
# 1     Afghanistan  AFG  1991           17.339286             59.889574
# 2     Afghanistan  AFG  1992           17.844703             62.307064
# 3     Afghanistan  AFG  1993           18.432649             65.135370
# 4     Afghanistan  AFG  1994           19.054541             67.597559
# ...           ...  ...   ...                 ...                   ...
# 6463     Zimbabwe  ZWE  2013           18.838860             87.285038
# 6464     Zimbabwe  ZWE  2014           19.137955             88.421400
# 6465     Zimbabwe  ZWE  2015           19.737721             90.955396
# 6466     Zimbabwe  ZWE  2016           20.438139             93.741546
# 6467     Zimbabwe  ZWE  2017           21.135722             96.488545
#
#       15-49 years (deaths)  Under-5s (deaths)  5-14 years (deaths)
# 0                78.273161                0.0                  0.0
# 1                80.165367                0.0                  0.0
# 2                91.996741                0.0                  0.0
# 3               107.428717                0.0                  0.0
# 4               115.108447                0.0                  0.0
# ...                    ...                ...                  ...
# 6463            196.004092                0.0                  0.0
# 6464            197.802713                0.0                  0.0
# 6465            204.039917                0.0                  0.0
# 6466            210.088148                0.0                  0.0
# 6467            215.370022                0.0                  0.0
#
# [6468 rows x 8 columns]

# %%
df1
# Out:
#             Entity Code  Year  \
# 0        Australia  AUS  2009
# 1        Australia  AUS  2010
# 2        Australia  AUS  2011
# 3        Australia  AUS  2012
# 4        Australia  AUS  2013
# ..             ...  ...   ...
# 312  United States  USA  2011
# 313  United States  USA  2012
# 314  United States  USA  2013
# 315  United States  USA  2014
# 316  United States  USA  2015
#
#      Total government spending percapita (per capita USD PPP)
# 0                                            15670.840
# 1                                            15484.240
# 2                                            16146.340
# 3                                            15628.890
# 4                                            17186.980
# ..                                                 ...
# 312                                          20796.711
# 313                                          20560.391
# 314                                          20410.400
# 315                                          20741.029
# 316                                          21157.320
#
# [317 rows x 4 columns]

# %%
len(list(df['Entity'].unique()))
# Out:
# 231

# %%
len(list(df1['Entity'].unique()))
# Out:
# 42

# %%
new_list = [x for x in list(set(df['Entity'])) if x not in list(set(df1['Entity']))]
new_list
# Out:
# ['Maldives',
#  'Algeria',
#  'High-income Asia Pacific',
#  'South Sudan',
#  'Kuwait',
#  'Southern Latin America',
#  'Libya',
#  'Rwanda',
#  'Afghanistan',
#  'China',
#  'Southeast Asia',
#  'World',
#  'Timor',
#  'Argentina',
#  'Seychelles',
#  'Ecuador',
#  'North Korea',
#  'Equatorial Guinea',
#  'Romania',
#  'Qatar',
#  'Sudan',
#  'Central Europe, Eastern Europe, and Central Asia',
#  'Ghana',
#  'Bulgaria',
#  'North America',
#  'Tanzania',
#  'Chad',
#  'Low-middle SDI',
#  'Zimbabwe',
#  'Congo',
#  'Micronesia (country)',
#  'Brunei',
#  'Montenegro',
#  'Guinea',
#  'Puerto Rico',
#  'Malaysia',
#  'Malawi',
#  'Middle SDI',
#  'Andean Latin America',
#  'Guatemala',
#  'Bangladesh',
#  'Iran',
#  'Barbados',
#  'Benin',
#  'Kyrgyzstan',
#  'Suriname',
#  'East Asia',
#  'Zambia',
#  'Georgia',
#  'Oceania',
#  'Albania',
#  'Samoa',
#  'Tajikistan',
#  'Laos',
#  'Western Europe',
#  'Andorra',
#  'Angola',
#  'American Samoa',
#  'Palestine',
#  'Peru',
#  'Central Europe',
#  'Thailand',
#  'Nigeria',
#  'Belarus',
#  'Togo',
#  'Saint Vincent and the Grenadines',
#  'Bhutan',
#  'Niger',
#  'Singapore',
#  'Cuba',
#  'Haiti',
#  'Democratic Republic of Congo',
#  'Northern Mariana Islands',
#  'Turkmenistan',
#  'Northern Ireland',
#  'High SDI',
#  'Liberia',
#  'Central Latin America',
#  'Ethiopia',
#  'Western Sub-Saharan Africa',
#  'Bahrain',
#  'Low SDI',
#  'Malta',
#  'Panama',
#  'Central Asia',
#  'Dominica',
#  'Guam',
#  'Mongolia',
#  'Sub-Saharan Africa',
#  'Madagascar',
#  'Australasia',
#  'Vanuatu',
#  'Eastern Sub-Saharan Africa',
#  'Sri Lanka',
#  'Central African Republic',
#  'Sao Tome and Principe',
#  'Uganda',
#  'Botswana',
#  'Southeast Asia, East Asia, and Oceania',
#  'Papua New Guinea',
#  'Venezuela',
#  'Myanmar',
#  'Honduras',
#  'Tropical Latin America',
#  'Nicaragua',
#  'Somalia',
#  'Yemen',
#  'Grenada',
#  'Bolivia',
#  'Caribbean',
#  'Mauritius',
#  'Greenland',
#  'Moldova',
#  'Dominican Republic',
#  'Cyprus',
#  'Saint Lucia',
#  'Kiribati',
#  'Bermuda',
#  'Gambia',
#  'Tunisia',
#  'Burkina Faso',
#  'Cambodia',
#  'Croatia',
#  'Solomon Islands',
#  'Eastern Europe',
#  'Trinidad and Tobago',
#  'Eritrea',
#  'High-middle SDI',
#  'Belize',
#  'Tonga',
#  'Cape Verde',
#  'Mozambique',
#  'Senegal',
#  'Vietnam',
#  'North Africa and Middle East',
#  'Brazil',
#  'Gabon',
#  'Philippines',
#  'Iraq',
#  'Namibia',
#  'Pakistan',
#  'El Salvador',
#  'Fiji',
#  'England',
#  'Chile',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Central Sub-Saharan Africa',
#  'Kazakhstan',
#  'Latin America and Caribbean',
#  'Sierra Leone',
#  'Uruguay',
#  'Lesotho',
#  'Southern Sub-Saharan Africa',
#  'Lebanon',
#  'Macedonia',
#  'Morocco',
#  'Marshall Islands',
#  'Bosnia and Herzegovina',
#  'United Arab Emirates',
#  'South Asia',
#  'Uzbekistan',
#  'Serbia',
#  'Jordan',
#  'Cameroon',
#  'Taiwan',
#  'Saudi Arabia',
#  'Swaziland',
#  'Azerbaijan',
#  'Comoros',
#  'Paraguay',
#  'Armenia',
#  'Mauritania',
#  'Oman',
#  'High-income',
#  'Nepal',
#  'Guyana',
#  'South Africa',
#  'Kenya',
#  'Guinea-Bissau',
#  'Scotland',
#  'Ukraine',
#  'Djibouti',
#  'Egypt',
#  'United States Virgin Islands',
#  'Wales',
#  "Cote d'Ivoire",
#  'Syria',
#  'Burundi',
#  'Mali',
#  'Jamaica']

# %%
new = df

for ent in new_list:
    new = new[new.Entity != ent]

# %%
new
# Out:
#              Entity Code  Year  70+ years (deaths)  50-69 years (deaths)  \
# 308       Australia  AUS  1990           72.896466            150.349219
# 309       Australia  AUS  1991           75.298186            150.410605
# 310       Australia  AUS  1992           80.125421            154.250836
# 311       Australia  AUS  1993           85.474570            156.970845
# 312       Australia  AUS  1994           93.410544            163.986814
# ...             ...  ...   ...                 ...                   ...
# 6099  United States  USA  2013         3090.908137          19600.410609
# 6100  United States  USA  2014         3426.728600          21774.250983
# 6101  United States  USA  2015         3816.403594          24005.583238
# 6102  United States  USA  2016         4379.795266          26560.983727
# 6103  United States  USA  2017         4807.637375          27406.962368
#
#       15-49 years (deaths)  Under-5s (deaths)  5-14 years (deaths)
# 308             489.190846           0.000000             0.000000
# 309             503.036782           0.000000             0.000000
# 310             547.823448           0.000000             0.000000
# 311             584.700186           0.000000             0.000000
# 312             672.141023           0.000000             0.000000
# ...                    ...                ...                  ...
# 6099          33548.590610           2.086135            10.466548
# 6100          36930.301943           2.568381            12.098709
# 6101          41643.143169           2.071642            10.732006
# 6102          47498.412197           0.000000             0.000000
# 6103          49383.611263           0.000000             0.000000
#
# [1120 rows x 8 columns]

# %%
df1
# Out:
#             Entity Code  Year  \
# 0        Australia  AUS  2009
# 1        Australia  AUS  2010
# 2        Australia  AUS  2011
# 3        Australia  AUS  2012
# 4        Australia  AUS  2013
# ..             ...  ...   ...
# 312  United States  USA  2011
# 313  United States  USA  2012
# 314  United States  USA  2013
# 315  United States  USA  2014
# 316  United States  USA  2015
#
#      Total government spending percapita (per capita USD PPP)
# 0                                            15670.840
# 1                                            15484.240
# 2                                            16146.340
# 3                                            15628.890
# 4                                            17186.980
# ..                                                 ...
# 312                                          20796.711
# 313                                          20560.391
# 314                                          20410.400
# 315                                          20741.029
# 316                                          21157.320
#
# [317 rows x 4 columns]

# %%
len(new['Entity'].unique())
# Out:
# 40

# %%
df1['Entity'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Colombia',
#        'Costa Rica', 'Czech Republic', 'Denmark', 'Estonia', 'Finland',
#        'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand',
#        'Norway', 'OECD - Average', 'OECD - Total', 'Poland', 'Portugal',
#        'Russia', 'Slovakia', 'Slovenia', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
new['Entity'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Colombia',
#        'Costa Rica', 'Czech Republic', 'Denmark', 'Estonia', 'Finland',
#        'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand',
#        'Norway', 'Poland', 'Portugal', 'Russia', 'Slovakia', 'Slovenia',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States'], dtype=object)

# %%
data = pd.merge(new, df1, on=['Entity', 'Year'])

# %%
data.head(20)
# Out:
#        Entity  Year  Total government spending percapita (per capita USD PPP)  \
# 0   Australia  2009                                          15670.840
# 1   Australia  2010                                          15484.240
# 2   Australia  2011                                          16146.340
# 3   Australia  2012                                          15628.890
# 4   Australia  2013                                          17186.980
# 5   Australia  2014                                          17146.650
# 6   Australia  2015                                          17482.539
# 7     Austria  2009                                          22185.570
# 8     Austria  2010                                          22243.160
# 9     Austria  2011                                          22631.250
# 10    Austria  2012                                          23800.010
# 11    Austria  2013                                          24457.000
# 12    Austria  2014                                          25635.939
# 13    Austria  2015                                          25543.160
# 14    Austria  2016                                          25610.250
# 15    Belgium  2009                                          20614.381
# 16    Belgium  2010                                          21428.160
# 17    Belgium  2011                                          22602.609
# 18    Belgium  2012                                          23820.539
# 19    Belgium  2013                                          24437.199
#
#          Deaths   Over
# 0   1416.522917  False
# 1   1439.252130  False
# 2   1454.194877   True
# 3   1449.744176  False
# 4   1503.284879   True
# 5   1619.781009   True
# 6   1710.244871   True
# 7    696.252670   True
# 8    697.189181   True
# 9    690.156528   True
# 10   685.447832   True
# 11   683.490346   True
# 12   678.229677   True
# 13   685.195373   True
# 14   669.528175   True
# 15   683.742908   True
# 16   688.959870   True
# 17   717.217248   True
# 18   751.253436   True
# 19   766.350943   True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 0 to 302
# Data columns (total 10 columns):
# Entity                                                      303 non-null object
# Code_x                                                      303 non-null object
# Year                                                        303 non-null int64
# 70+ years (deaths)                                          303 non-null float64
# 50-69 years (deaths)                                        303 non-null float64
# 15-49 years (deaths)                                        303 non-null float64
# Under-5s (deaths)                                           303 non-null float64
# 5-14 years (deaths)                                         303 non-null float64
# Code_y                                                      303 non-null object
# Total government spending percapita (per capita USD PPP)    303 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 26.0+ KB

# %%
die1 = data['70+ years (deaths)'] + data['50-69 years (deaths)'] + data['15-49 years (deaths)'] 
die2 = data['5-14 years (deaths)'] + data['Under-5s (deaths)'] 
deaths = die1 + die2
data['Deaths'] = deaths

# %%
data = data.drop(["Code_x", "Code_y",'5-14 years (deaths)','Under-5s (deaths)'], axis=1)

# %%
data = data.drop(['70+ years (deaths)','50-69 years (deaths)','15-49 years (deaths)'], axis=1 )
data.head(100)
# Out:
#        Entity  Year  Total government spending percapita (per capita USD PPP)  \
# 0   Australia  2009                                           15670.84
# 1   Australia  2010                                           15484.24
# 2   Australia  2011                                           16146.34
# 3   Australia  2012                                           15628.89
# 4   Australia  2013                                           17186.98
# ..        ...   ...                                                ...
# 95     Greece  2012                                           14007.03
# 96     Greece  2013                                           16248.15
# 97     Greece  2014                                           13375.41
# 98     Greece  2015                                           14288.74
# 99     Greece  2016                                           13128.37
#
#          Deaths
# 0   1416.522917
# 1   1439.252130
# 2   1454.194877
# 3   1449.744176
# 4   1503.284879
# ..          ...
# 95   282.210238
# 96   250.886846
# 97   239.824802
# 98   249.240247
# 99   240.804926
#
# [100 rows x 4 columns]

# %%
data['Total government spending percapita (per capita USD PPP)'].mean()
# Out:
# 15747.373379537956

# %%
data['Over'] = data['Total government spending percapita (per capita USD PPP)'] > 15747.3
data
# Out:
#             Entity  Year  \
# 0        Australia  2009
# 1        Australia  2010
# 2        Australia  2011
# 3        Australia  2012
# 4        Australia  2013
# ..             ...   ...
# 298  United States  2011
# 299  United States  2012
# 300  United States  2013
# 301  United States  2014
# 302  United States  2015
#
#      Total government spending percapita (per capita USD PPP)        Deaths  \
# 0                                            15670.840          1416.522917
# 1                                            15484.240          1439.252130
# 2                                            16146.340          1454.194877
# 3                                            15628.890          1449.744176
# 4                                            17186.980          1503.284879
# ..                                                 ...                  ...
# 298                                          20796.711         47700.832587
# 299                                          20560.391         51472.014917
# 300                                          20410.400         56252.462040
# 301                                          20741.029         62145.948617
# 302                                          21157.320         69477.933649
#
#       Over
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 298   True
# 299   True
# 300   True
# 301   True
# 302   True
#
# [303 rows x 5 columns]

# %%
AT = data[data['Over']==True]
AT
# Out:
#             Entity  Year  \
# 2        Australia  2011
# 4        Australia  2013
# 5        Australia  2014
# 6        Australia  2015
# 7          Austria  2009
# ..             ...   ...
# 298  United States  2011
# 299  United States  2012
# 300  United States  2013
# 301  United States  2014
# 302  United States  2015
#
#      Total government spending percapita (per capita USD PPP)        Deaths  \
# 2                                            16146.340          1454.194877
# 4                                            17186.980          1503.284879
# 5                                            17146.650          1619.781009
# 6                                            17482.539          1710.244871
# 7                                            22185.570           696.252670
# ..                                                 ...                  ...
# 298                                          20796.711         47700.832587
# 299                                          20560.391         51472.014917
# 300                                          20410.400         56252.462040
# 301                                          20741.029         62145.948617
# 302                                          21157.320         69477.933649
#
#      Over
# 2    True
# 4    True
# 5    True
# 6    True
# 7    True
# ..    ...
# 298  True
# 299  True
# 300  True
# 301  True
# 302  True
#
# [143 rows x 5 columns]

# %%
BT = data[data['Over']==False]
BT
# Out:
#         Entity  Year  \
# 0    Australia  2009
# 1    Australia  2010
# 3    Australia  2012
# 31    Colombia  2009
# 32    Colombia  2010
# ..         ...   ...
# 283     Turkey  2011
# 284     Turkey  2012
# 285     Turkey  2013
# 286     Turkey  2014
# 287     Turkey  2015
#
#      Total government spending percapita (per capita USD PPP)       Deaths  \
# 0                                           15670.8400         1416.522917
# 1                                           15484.2400         1439.252130
# 3                                           15628.8900         1449.744176
# 31                                           3551.1399          274.935452
# 32                                           3680.4399          283.801705
# ..                                                 ...                 ...
# 283                                          6868.8398          495.343667
# 284                                          7204.6499          533.936376
# 285                                          7690.0801          585.804674
# 286                                          7830.6401          658.833798
# 287                                          8052.9399          695.488945
#
#       Over
# 0    False
# 1    False
# 3    False
# 31   False
# 32   False
# ..     ...
# 283  False
# 284  False
# 285  False
# 286  False
# 287  False
#
# [160 rows x 5 columns]

# %%
sns.distplot(data['Total government spending percapita (per capita USD PPP)']);

# %%
sns.distplot(data['Deaths']);

# %%
sns.set_style('darkgrid') #Pretty background including grid lines for our backdrop
plt.hist(BT['Total government spending percapita (per capita USD PPP)'], bins=100);

# %%
sample_means_A = []
for i in range(10**4):
    sample = AT.sample(n=50) #Take a sample of 50 people
    sample_means_A.append(sample.Deaths.mean()) #Calculate the sample mean

# %%
sample_means_B = []
for i in range(10**4):
    sample = BT.sample(n=50) #Take a sample of 50 people
    sample_means_B.append(sample.Deaths.mean()) #Calculate the sample mean

# %%
sns.distplot(sample_means_A)
sns.distplot(sample_means_B)

# %%
'''
ctrl_q1 = OrderDetail_df[OrderDetail_df[‘Discount’]==0][‘Quantity’]
exper_q1 = OrderDetail_df[OrderDetail_df[‘Discount’]!=0][‘Quantity’]
plt.figure(figsize=(20, 10))
sns.distplot(control, label=‘Control’)
sns.set_color_codes(“muted”)
sns.distplot(experimental, label=‘Experimental’ )
plt.title(‘Control vs experimental’,fontsize=30)
plt.xlabel(‘Quantity’,fontsize=20)
plt.legend();
'''

# %%
data.to_csv('Bdata.csv', index= False)
