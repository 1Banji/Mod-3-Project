# %% [markdown]
# ## Does increasing the amount of government spending on its citizens decreases the amount of CO2 emission per capita?
#
# What does CO2 emission mean?
#
#
# #### What does Goverment spending on its citizens mean?
#
#  Public spending also shows that governments around the world often rely on the private sector to produce and manage goods and services. And public-private partnerships (PPP), in particular, have become an increasingly popular mechanism for governments to finance, design, build and operate infrastructure projects
# The steep growth of social spending in the second half of the 20th century was largely driven by the expansion of public funding for healthcare and education.
#
#
# #### Objectives
# The definition of spending on citizens and effects of
#
#
# Which tests to run?
#
# #### Hypothesis
# H0 = Government spending on its citizens does not have a effect on C02 emission per capita?
# HA = Govenrment spending on its citizens decreases the C02 emission per capita?
#
#
# How are we going to test and find significance
#
# is it T-test or
#
#
# ### Create a class for countries that runs everthing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv('../dataset/social-spending-oecd-longrun.csv')
co = pd.read_csv('../dataset/co-emissions-per-capita.csv')

display(df.head())
display(co.head())
# Out:
#       Entity Code  Year  \
# 0  Australia  AUS  1880
# 1  Australia  AUS  1890
# 2  Australia  AUS  1900
# 3  Australia  AUS  1910
# 4  Australia  AUS  1920
#
#   Social Expenditure %GDP - (OWID extrapolated series) (%)
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                               1.12
# 4                                               1.66
#         Entity Code  Year  Per capita CO₂ emissions (tonnes per capita)
# 0  Afghanistan  AFG  1800                                           0.0
# 1  Afghanistan  AFG  1801                                           0.0
# 2  Afghanistan  AFG  1802                                           0.0
# 3  Afghanistan  AFG  1803                                           0.0
# 4  Afghanistan  AFG  1804                                           0.0

# %%
co = co[co.Year > 1990]

# %%
# Find only 
UKCO = co[co.Entity == 'United Kingdom']
UKGDP = df[df.Entity == 'United Kingdom']

UKCO = UK[UK.Year > 1995]
UKGDP = UKGDP[UKGDP.Year > 1995]
UKGDP.rename(columns={'Social Expenditure %GDP - (OWID extrapolated series) (%)':'GDP_Percentage'})
UKCO.rename(columns={'Per capita CO₂ emissions (tonnes per capita)':'CO2_Emission'})
# Out:
#            Entity Code  Year  CO2_Emission  \
# 0  United Kingdom  GBR  2010      8.090978
# 1  United Kingdom  GBR  2013      7.390538
# 2  United Kingdom  GBR  2014      6.747467
# 3  United Kingdom  GBR  2015      6.463019
# 4  United Kingdom  GBR  2016      6.058056
#
#   Social Expenditure %GDP - (OWID extrapolated series) (%)
# 0                                             22.785
# 1                                             21.874
# 2                                              21.58
# 3                                             21.502
# 4                                             21.493

# %%
UK = pd.merge(UKCO,UKGDP)

# %%
UKGDP.head()
# Out:
#              Entity Code  Year  \
# 773  United Kingdom  GBR  2000
# 774  United Kingdom  GBR  2005
# 775  United Kingdom  GBR  2010
# 776  United Kingdom  GBR  2013
# 777  United Kingdom  GBR  2014
#
#     Social Expenditure %GDP - (OWID extrapolated series) (%)
# 773                                             17.706
# 774                                             19.408
# 775                                             22.785
# 776                                             21.874
# 777                                              21.58

# %%
plt.figure(figsize=(16,10))
plt.subplot(121)
sns.lineplot('Year','Per capita CO₂ emissions (tonnes per capita)',data=UK)
plt.subplot(122)
sns.lineplot('Year','Total government spending percapita (per capita USD PPP)',data=UKGDP)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-1449154c1a09> in <module>()
#       3 sns.lineplot('Year','Per capita CO₂ emissions (tonnes per capita)',data=UK)
#       4 plt.subplot(122)
# ----> 5 sns.lineplot('Year','Total government spending percapita (per capita USD PPP)',data=UKGDP)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ...
